# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("./data/sales_pred.txt")
df = df.reset_index()
df = df.replace(to_replace ="Seafood", value ="Others")
df = df.replace(to_replace ="Starchy Foods", value ="Others")
df = df.replace(to_replace ="Breakfast", value ="Others")
df = df.replace(to_replace ="Seafood", value ="Others")
df = df.replace(to_replace ="Hard Drinks", value ="Others")
df['Item_Visibility']=df['Item_Visibility'].replace(0,df['Item_Visibility'].mean())
df
# Out:
#       index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         0           FDA15        9.300          Low Fat         0.016047
# 1         1           DRC01        5.920          Regular         0.019278
# 2         2           FDN15       17.500          Low Fat         0.016760
# 3         3           FDX07       19.200          Regular         0.066132
# 4         4           NCD19        8.930          Low Fat         0.066132
# 5         5           FDP36       10.395          Regular         0.066132
# 6         6           FDO10       13.650          Regular         0.012741
# 7         7           FDP10          NaN          Low Fat         0.127470
# 8         8           FDH17       16.200          Regular         0.016687
# 9         9           FDU28       19.200          Regular         0.094450
# 10       10           FDY07       11.800          Low Fat         0.066132
# ...

# %%
#df.Outlet_Identifier.unique()
#out = df[df.Outlet_Identifier=='OUT017']
#df['Outlet_Size'].fillna('Small',inplace=True)
df.Item_Visibility.mean()
# Out:
# 0.0702133906395318

# %%
df.Outlet_Establishment_Year = df.Outlet_Establishment_Year.max()-df.Outlet_Establishment_Year
df
# Out:
#       index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         0           FDA15        9.300          Low Fat         0.016047
# 1         1           DRC01        5.920          Regular         0.019278
# 2         2           FDN15       17.500          Low Fat         0.016760
# 3         3           FDX07       19.200          Regular         0.066132
# 4         4           NCD19        8.930          Low Fat         0.066132
# 5         5           FDP36       10.395          Regular         0.066132
# 6         6           FDO10       13.650          Regular         0.012741
# 7         7           FDP10          NaN          Low Fat         0.127470
# 8         8           FDH17       16.200          Regular         0.016687
# 9         9           FDU28       19.200          Regular         0.094450
# 10       10           FDY07       11.800          Low Fat         0.066132
# ...

# %%
df.Outlet_Size.value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df.Item_Type.value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Others                    705
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Name: Item_Type, dtype: int64

# %%
x = df.Outlet_Identifier.unique()
for  i in x:
    out = df[df.Outlet_Identifier==i]
    print(i)
    print(out.isna().any()[9])
# Out:
# OUT049
# False
# OUT018
# False
# OUT010
# True
# OUT013
# False
# OUT027
# False
# OUT045
# True
# OUT017
# True
# OUT046
# False
# OUT035
# False
# OUT019
# False

# %%
df.count
# Out:
# <bound method DataFrame.count of       index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         0           FDA15        9.300          Low Fat         0.016047
# 1         1           DRC01        5.920          Regular         0.019278
# 2         2           FDN15       17.500          Low Fat         0.016760
# 3         3           FDX07       19.200          Regular         0.066132
# 4         4           NCD19        8.930          Low Fat         0.066132
# 5         5           FDP36       10.395          Regular         0.066132
# 6         6           FDO10       13.650          Regular         0.012741
# 7         7           FDP10          NaN          Low Fat         0.127470
# 8         8           FDH17       16.200          Regular         0.016687
# 9         9           FDU28       19.200          Regular         0.094450
# 10       10           FDY07       11.800          Low Fat         0.066132
# ...

# %%
import seaborn as sns
sns.pairplot(df)
# Out:
# /home/saujanya/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/saujanya/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
fat_content = df.Item_Fat_Content.unique()
item_type = df.Item_Type.unique()
outlet_identifier = df.Outlet_Identifier.unique()

# %%
#Analysis acc to OUTLET
for i in outlet_identifier:
    outlet = df[df.Outlet_Identifier==i]
    out_cnt = outlet.count()[0]
    perc = (out_cnt/8523)*100
    print("------------"+i+"-------------")
    print("% contribution : "+str(perc))
    item_type = outlet.Item_Type.unique()
    max_sales=0
    min_sales=50000000
    for j in item_type:
        type_df = outlet[outlet.Item_Type==j]
        temp1 = type_df.Item_Outlet_Sales.max()
        if temp1>max_sales:
            max_sales = temp1
            mx = j
        temp2 = type_df.Item_Outlet_Sales.min()
        if temp2<min_sales:
            min_sales=temp2
            mn = j
    print("Maximum : "+str(max_sales)+" -> "+mx)
    print("Minimum : "+str(min_sales)+" -> "+mn)
# Out:
# ------------OUT049-------------
# % contribution : 10.91165082717353
# Maximum : 7646.0472 -> Dairy
# Minimum : 111.8544 -> Fruits and Vegetables
# ------------OUT018-------------
# % contribution : 10.888184911416168
# Maximum : 6768.5228 -> Canned
# Minimum : 69.2432 -> Household
# ------------OUT010-------------
# % contribution : 6.511791622668074
# Maximum : 1775.6886 -> Household
# Minimum : 33.29 -> Household
# ------------OUT013-------------
# % contribution : 10.935116742930893
# Maximum : 10256.649 -> Dairy
# Minimum : 73.238 -> Household
# ------------OUT027-------------
# % contribution : 10.970315616566936
# Maximum : 13086.9648 -> Household
# Minimum : 241.6854 -> Health and Hygiene
# ------------OUT045-------------
# % contribution : 10.89991786929485
# Maximum : 8994.958 -> Fruits and Vegetables
# Minimum : 99.87 -> Household
# ------------OUT017-------------
# % contribution : 10.864718995658805
# Maximum : 9664.7528 -> Dairy
# Minimum : 143.8128 -> Household
# ...

# %%
vis = df.Item_Visibility.unique()
plt.plot(vis,'or',markersize=0.2)

# %%
df.boxplot(column=['Item_Visibility'])

# %%
df1=df[df['Item_Visibility']>0.025]
df2=df1[df['Item_Visibility']<0.1]
df2
# Out:
# /home/saujanya/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3         3           FDX07       19.200          Regular         0.066132
# 4         4           NCD19        8.930          Low Fat         0.066132
# 5         5           FDP36       10.395          Regular         0.066132
# 9         9           FDU28       19.200          Regular         0.094450
# 10       10           FDY07       11.800          Low Fat         0.066132
# 11       11           FDA03       18.500          Regular         0.045464
# 13       13           FDS46       17.600          Regular         0.047257
# 14       14           FDF32       16.350          Low Fat         0.068024
# 15       15           FDP49        9.000          Regular         0.069089
# ...

# %%
df['Item_Visibility'].plot.kde()

# %%
df.describe()
# Out:
#              index  Item_Weight  Item_Visibility     Item_MRP  \
# count  8523.000000  7060.000000      8523.000000  8523.000000
# mean   4261.000000    12.857645         0.070213   140.992782
# std    2460.522505     4.643456         0.048742    62.275067
# min       0.000000     4.555000         0.003575    31.290000
# 25%    2130.500000     8.773750         0.033085    93.826500
# 50%    4261.000000    12.600000         0.062517   143.012800
# 75%    6391.500000    16.850000         0.094585   185.643700
# max    8522.000000    21.350000         0.328391   266.888400
#
#        Outlet_Establishment_Year  Item_Outlet_Sales
# count                8523.000000        8523.000000
# mean                   11.168133        2181.288914
# std                     8.371760        1706.499616
# min                     0.000000          33.290000
# 25%                     5.000000         834.247400
# 50%                    10.000000        1794.331000
# ...

# %%
'''df.Item_Identifier.value_counts()'''
# Out:
# 'df.Item_Identifier.value_counts()'

# %%
df.Item_Visibility.value_counts()
# Out:
# 0.066132    526
# 0.076975      3
# 0.096592      2
# 0.104784      2
# 0.058919      2
# 0.076792      2
# 0.061425      2
# 0.023466      2
# 0.112399      2
# 0.159721      2
# 0.128296      2
# 0.093308      2
# 0.072411      2
# 0.074931      2
# 0.041355      2
# 0.071833      2
# 0.097457      2
# 0.136286      2
# 0.078759      2
# 0.080625      2
# 0.085622      2
# 0.013952      2
# 0.079806      2
# 0.106539      2
# 0.093914      2
# 0.014048      2
# 0.026895      2
# 0.080969      2
# 0.122016      2
# 0.072285      2
#            ...
# 0.021240      1
# 0.100641      1
# 0.030921      1
# 0.118859      1
# 0.162572      1
# 0.076745      1
# 0.015461      1
# 0.057655      1
# 0.042113      1
# 0.029565      1
# 0.066447      1
# 0.035954      1
# 0.083222      1
# 0.021413      1
# 0.099024      1
# 0.052811      1
# 0.122735      1
# 0.118080      1
# 0.046654      1
# 0.021469      1
# 0.060134      1
# 0.096658      1
# 0.019064      1
# 0.164197      1
# ...

# %%
df.count()
# Out:
# index                        8523
# Item_Identifier              8523
# Item_Weight                  7060
# Item_Fat_Content             8523
# Item_Visibility              8523
# Item_Type                    8523
# Item_MRP                     8523
# Outlet_Identifier            8523
# Outlet_Establishment_Year    8523
# Outlet_Size                  6113
# Outlet_Location_Type         8523
# Outlet_Type                  8523
# Item_Outlet_Sales            8523
# dtype: int64

# %%
df.Item_Weight.value_counts()
# Out:
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
# 9.300     68
# 16.700    66
# 10.500    66
# 19.350    63
# 20.700    62
# 16.000    62
# 9.800     61
# 17.700    60
# 17.750    60
# 15.000    59
# 18.850    59
# 15.850    59
# 16.750    58
# 18.250    58
# 19.600    58
# 15.700    57
# 12.500    56
# 9.195     56
# 20.200    53
# 12.100    53
# 10.195    53
# 12.600    53
# 15.600    52
# 13.500    51
# 11.500    51
#           ..
# 5.305      3
# 6.305      3
# 7.710      3
# 7.105      3
# 5.825      3
# 6.460      3
# 5.425      3
# 6.895      2
# 8.920      2
# 6.325      2
# 6.400      2
# 4.905      2
# 5.675      2
# 5.155      2
# 7.275      2
# 5.210      2
# 8.485      2
# 8.800      2
# 5.885      2
# 7.605      2
# 6.405      2
# 5.735      2
# 8.670      2
# 6.775      2
# 7.890      2
# 7.560      2
# 9.420      1
# 5.400      1
# 6.520      1
# 7.685      1
# Name: Item_Weight, Length: 415, dtype: int64

# %%
df.Outlet_Size.value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
tier = df.Outlet_Location_Type.unique()
tot = df.Item_Outlet_Sales.sum()
for i in tier:
    t = df[df.Outlet_Location_Type==i]
    print(str(i)+" : "+str((t.Item_Outlet_Sales.sum()/tot)*100))
    print(t.Item_Outlet_Sales.sum())
# Out:
# Tier 1 : 24.108594681915854
# 4482059.072000001
# Tier 3 : 41.07740905092249
# 7636752.631999999
# Tier 2 : 34.81399626716168
# 6472313.7064000005

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
# index                        8523 non-null int64
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 865.7+ KB

# %%
df.Item_Weight
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
# 5       10.395
# 6       13.650
# 7          NaN
# 8       16.200
# 9       19.200
# 10      11.800
# 11      18.500
# 12      15.100
# 13      17.600
# 14      16.350
# 15       9.000
# 16      11.800
# 17       9.000
# 18         NaN
# 19      13.350
# 20      18.850
# 21         NaN
# 22      14.600
# 23         NaN
# 24      13.850
# 25      13.000
# 26       7.645
# 27      11.650
# 28       5.925
# 29         NaN
#          ...
# 8493     7.420
# 8494    15.200
# 8495     9.695
# 8496     7.420
# 8497    13.650
# 8498    15.350
# 8499    11.600
# 8500    20.350
# 8501     5.340
# 8502     8.420
# 8503    20.500
# 8504       NaN
# 8505    10.500
# 8506    17.250
# 8507     5.880
# 8508    11.350
# 8509     8.100
# 8510    13.800
# 8511    17.500
# 8512    20.700
# 8513    12.000
# 8514    15.000
# 8515    20.700
# 8516    18.600
# 8517    20.750
# 8518     6.865
# 8519     8.380
# ...

# %%
df.describe()
# Out:
#              index  Item_Weight  Item_Visibility     Item_MRP  \
# count  8523.000000  7060.000000      8523.000000  8523.000000
# mean   4261.000000    12.857645         0.070213   140.992782
# std    2460.522505     4.643456         0.048742    62.275067
# min       0.000000     4.555000         0.003575    31.290000
# 25%    2130.500000     8.773750         0.033085    93.826500
# 50%    4261.000000    12.600000         0.062517   143.012800
# 75%    6391.500000    16.850000         0.094585   185.643700
# max    8522.000000    21.350000         0.328391   266.888400
#
#        Outlet_Establishment_Year  Item_Outlet_Sales
# count                8523.000000        8523.000000
# mean                   11.168133        2181.288914
# std                     8.371760        1706.499616
# min                     0.000000          33.290000
# 25%                     5.000000         834.247400
# 50%                    10.000000        1794.331000
# ...

# %%
df.Item_Identifier.value_counts()
# Out:
# FDG33    10
# FDW13    10
# DRN47     9
# FDW26     9
# NCB18     9
# FDW49     9
# FDX04     9
# FDP25     9
# NCF42     9
# FDU12     9
# FDG09     9
# FDF56     9
# NCQ06     9
# NCJ30     9
# NCL31     9
# FDO19     9
# FDX31     9
# FDD38     9
# FDT07     9
# FDQ40     9
# DRE49     9
# NCY18     9
# FDV60     9
# NCI54     9
# FDF52     9
# FDV38     9
# FDX20     9
# NCL53     8
# FDR23     8
# DRF01     8
#          ..
# FDF38     2
# FDT33     2
# FDU43     2
# FDM16     2
# FDD22     2
# DRE01     2
# FDW10     2
# FDP15     2
# FDE39     2
# FDH22     2
# DRI59     2
# FDI36     2
# NCC55     2
# NCW30     2
# FDA48     2
# FDZ50     2
# FDB47     2
# FDU09     2
# FDG28     2
# FDW58     2
# NCX53     2
# FDC23     1
# FDO33     1
# FDK57     1
# FDY43     1
# FDQ60     1
# FDN52     1
# DRF48     1
# FDT35     1
# FDE52     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
#plt.hist(df.Item_Outlet_Sales)

# %%
sns.distplot(df.Item_Outlet_Sales)

# %%
df.dtypes
# Out:
# index                          int64
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
n_ft = df[['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year','Item_Outlet_Sales']]

# %%
corr = n_ft.corr()
corr
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.020416  0.027141
# Item_Visibility              -0.020416         1.000000 -0.005259
# Item_MRP                      0.027141        -0.005259  1.000000
# Outlet_Establishment_Year     0.011588         0.078355 -0.005020
# Item_Outlet_Sales             0.014123        -0.134138  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                 0.011588           0.014123
# Item_Visibility                             0.078355          -0.134138
# Item_MRP                                   -0.005020           0.567574
# Outlet_Establishment_Year                   1.000000           0.049135
# Item_Outlet_Sales                           0.049135           1.000000

# %%
corr['Item_Outlet_Sales'].sort_values()
# Out:
# Item_Visibility             -0.134138
# Item_Weight                  0.014123
# Outlet_Establishment_Year    0.049135
# Item_MRP                     0.567574
# Item_Outlet_Sales            1.000000
# Name: Item_Outlet_Sales, dtype: float64

# %%
plt.plot(df.Item_Outlet_Sales,df.Item_Visibility,'ro',markersize=2)

# %%
df.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
sns.countplot(df.Item_Fat_Content)

# %%
plt.plot(df.Item_Visibility, df.Item_Outlet_Sales,'or',markersize=0.5)

# %%
plt.bar(df.Outlet_Establishment_Year,df.Item_Outlet_Sales)
# Out:
# <BarContainer object of 8523 artists>

# %%
'''avg = round(n_ft.Item_Weight.mean(),2)
n_ft['Item_Weight'].fillna(avg,inplace=True)'''
# Out:
# "avg = round(n_ft.Item_Weight.mean(),2)\nn_ft['Item_Weight'].fillna(avg,inplace=True)"

# %%
'''n_ft.Item_Weight = round(n_ft.Item_Weight,0)
n_ft.Item_Visibility = round(n_ft.Item_Visibility,0)
n_ft.Item_MRP = round(n_ft.Item_MRP,0)
n_ft.Item_Outlet_Sales = round(n_ft.Item_Outlet_Sales,0)

n_ft = n_ft.astype(int)'''
# Out:
# 'n_ft.Item_Weight = round(n_ft.Item_Weight,0)\nn_ft.Item_Visibility = round(n_ft.Item_Visibility,0)\nn_ft.Item_MRP = round(n_ft.Item_MRP,0)\nn_ft.Item_Outlet_Sales = round(n_ft.Item_Outlet_Sales,0)\n\nn_ft = n_ft.astype(int)'

# %%
n_ft.dtypes
# Out:
# Item_Weight                  float64
# Item_Visibility              float64
# Item_MRP                     float64
# Outlet_Establishment_Year      int64
# Item_Outlet_Sales            float64
# dtype: object

# %%
'''df = df.dropna(subset=['Item_Weight','Item_Fat_Content','Item_Visibility','Item_Type','Item_MRP','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Outlet_Location_Type','Outlet_Type','Item_Outlet_Sales'])
df'''
df
# Out:
#       index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         0           FDA15        9.300          Low Fat         0.016047
# 1         1           DRC01        5.920          Regular         0.019278
# 2         2           FDN15       17.500          Low Fat         0.016760
# 3         3           FDX07       19.200          Regular         0.066132
# 4         4           NCD19        8.930          Low Fat         0.066132
# 5         5           FDP36       10.395          Regular         0.066132
# 6         6           FDO10       13.650          Regular         0.012741
# 7         7           FDP10          NaN          Low Fat         0.127470
# 8         8           FDH17       16.200          Regular         0.016687
# 9         9           FDU28       19.200          Regular         0.094450
# 10       10           FDY07       11.800          Low Fat         0.066132
# ...

# %%
'''del df['Item_Identifier']
del df['Item_Fat_Content']
del df['Outlet_Identifier']
del df['Outlet_Size']
del df['Outlet_Type']
del df['Item_Type']'''
new_df = df.drop(['Item_Weight','Item_Identifier','Item_Fat_Content','Outlet_Identifier'],axis=1)
fin = pd.get_dummies(new_df)
fin.columns
# Out:
# Index(['index', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year',
#        'Item_Outlet_Sales', 'Item_Type_Baking Goods', 'Item_Type_Breads',
#        'Item_Type_Canned', 'Item_Type_Dairy', 'Item_Type_Frozen Foods',
#        'Item_Type_Fruits and Vegetables', 'Item_Type_Health and Hygiene',
#        'Item_Type_Household', 'Item_Type_Meat', 'Item_Type_Others',
#        'Item_Type_Snack Foods', 'Item_Type_Soft Drinks', 'Outlet_Size_High',
#        'Outlet_Size_Medium', 'Outlet_Size_Small',
#        'Outlet_Location_Type_Tier 1', 'Outlet_Location_Type_Tier 2',
#        'Outlet_Location_Type_Tier 3', 'Outlet_Type_Grocery Store',
#        'Outlet_Type_Supermarket Type1', 'Outlet_Type_Supermarket Type2',
#        'Outlet_Type_Supermarket Type3'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(fin,test_size=0.2,random_state=3)

# %%
train_x = train[['Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year',
       'Item_Type_Baking Goods', 'Item_Type_Breads',
       'Item_Type_Canned', 'Item_Type_Dairy', 'Item_Type_Frozen Foods',
       'Item_Type_Fruits and Vegetables', 'Item_Type_Health and Hygiene',
       'Item_Type_Household', 'Item_Type_Meat', 'Item_Type_Others',
       'Item_Type_Snack Foods', 'Item_Type_Soft Drinks', 'Outlet_Size_High',
       'Outlet_Size_Medium', 'Outlet_Size_Small',
       'Outlet_Location_Type_Tier 1', 'Outlet_Location_Type_Tier 2',
       'Outlet_Location_Type_Tier 3', 'Outlet_Type_Grocery Store',
       'Outlet_Type_Supermarket Type1', 'Outlet_Type_Supermarket Type2',
       'Outlet_Type_Supermarket Type3']]
train_y = train[['Item_Outlet_Sales']]

test_x = test[['Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year',
       'Item_Type_Baking Goods', 'Item_Type_Breads',
       'Item_Type_Canned', 'Item_Type_Dairy', 'Item_Type_Frozen Foods',
       'Item_Type_Fruits and Vegetables', 'Item_Type_Health and Hygiene',
       'Item_Type_Household', 'Item_Type_Meat', 'Item_Type_Others',
       'Item_Type_Snack Foods', 'Item_Type_Soft Drinks', 'Outlet_Size_High',
       'Outlet_Size_Medium', 'Outlet_Size_Small',
       'Outlet_Location_Type_Tier 1', 'Outlet_Location_Type_Tier 2',
       'Outlet_Location_Type_Tier 3', 'Outlet_Type_Grocery Store',
       'Outlet_Type_Supermarket Type1', 'Outlet_Type_Supermarket Type2',
       'Outlet_Type_Supermarket Type3']]
test_y = test[['Item_Outlet_Sales']]

# %%
regr = RandomForestRegressor()
regr.fit(train_x,train_y)
#train_x.Item_Weight.info()
# Out:
# /home/saujanya/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/saujanya/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
regr.score(test_x,test_y)
# Out:
# 0.5532055925759161
