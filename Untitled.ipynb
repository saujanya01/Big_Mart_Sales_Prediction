# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df = pd.read_csv("./data/sales_pred.txt")
df = df.reset_index()
df = df.replace(to_replace ="Seafood", value ="Others")
df = df.replace(to_replace ="Starchy Foods", value ="Others")
df = df.replace(to_replace ="Breakfast", value ="Others")
df = df.replace(to_replace ="Seafood", value ="Others")
df = df.replace(to_replace ="Hard Drinks", value ="Others")
df
# Out:
#       index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         0           FDA15        9.300          Low Fat         0.016047
# 1         1           DRC01        5.920          Regular         0.019278
# 2         2           FDN15       17.500          Low Fat         0.016760
# 3         3           FDX07       19.200          Regular         0.000000
# 4         4           NCD19        8.930          Low Fat         0.000000
# 5         5           FDP36       10.395          Regular         0.000000
# 6         6           FDO10       13.650          Regular         0.012741
# 7         7           FDP10          NaN          Low Fat         0.127470
# 8         8           FDH17       16.200          Regular         0.016687
# 9         9           FDU28       19.200          Regular         0.094450
# 10       10           FDY07       11.800          Low Fat         0.000000
# ...

# %%
df = df.replace(to_replace="Low fat",value="Low Fat")
#df = df.replace(to_replace="low fat",value="Low fat")
df = df.replace(to_replace="reg",value="Regular")df.Item_Fat_Content.value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
df
# Out:
#       index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         0           FDA15        9.300          Low Fat         0.016047
# 1         1           DRC01        5.920          Regular         0.019278
# 2         2           FDN15       17.500          Low Fat         0.016760
# 3         3           FDX07       19.200          Regular         0.000000
# 4         4           NCD19        8.930          Low Fat         0.000000
# 5         5           FDP36       10.395          Regular         0.000000
# 6         6           FDO10       13.650          Regular         0.012741
# 7         7           FDP10          NaN          Low Fat         0.127470
# 8         8           FDH17       16.200          Regular         0.016687
# 9         9           FDU28       19.200          Regular         0.094450
# 10       10           FDY07       11.800          Low Fat         0.000000
# ...

# %%
df[df.Item_Identifier=='FDP10']
# Out:
#       index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7         7           FDP10          NaN          Low Fat         0.127470
# 585     585           FDP10         19.0          Low Fat         0.128066
# 2623   2623           FDP10         19.0          Low Fat         0.128815
# 3382   3382           FDP10         19.0          Low Fat         0.128289
# 4585   4585           FDP10         19.0          Low Fat         0.128090
# 6087   6087           FDP10         19.0          Low Fat         0.128350
# 7883   7883           FDP10         19.0          Low Fat         0.127984
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 7     Snack Foods  107.7622            OUT027                       1985
# 585   Snack Foods  104.3622            OUT035                       2004
# 2623  Snack Foods  107.6622            OUT017                       2007
# 3382  Snack Foods  104.9622            OUT049                       1999
# ...

# %%
iden = df.Item_Identifier.unique()
iden
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCF55', 'NCW30', 'NCW05'],
#       dtype=object)

# %%
mx=0
for i in iden:
    mx=df[df.Item_Identifier==i].max()
    df[df.Item_Identifier==i].Item_Weight=mx
